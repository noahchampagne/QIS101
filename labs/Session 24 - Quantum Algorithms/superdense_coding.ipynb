# %%
# superdense_coding.ipynb

# Cell 1

import matplotlib.pyplot as plt
import numpy as np
import qiskit
from IPython.display import Math
from qiskit import (
    Aer,
    ClassicalRegister,
    QuantumCircuit,
    QuantumRegister,
    assemble,
    execute,
)
from qiskit.quantum_info import Statevector
from qiskit.visualization import (
    array_to_latex,
    plot_bloch_multivector,
    plot_histogram,
    plot_state_qsphere,
)

backend = Aer.get_backend("aer_simulator")

qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.save_statevector("sv1")

n = 0

if n & 2 == 2:
    qc.x(0)
if n & 1 == 1:
    qc.z(0)

qc.cx(0, 1)
qc.h(0)
qc.save_statevector()
qc.measure_all()

result = execute(qc, backend, shots=1).result()
counts = result.get_counts()

display(qc.draw(output="mpl", scale=1.5))

sv1 = result.data(0)["sv1"]
sv2 = result.get_statevector()

display(array_to_latex(sv1, prefix="\\text{Statevector 1} = "))
display(array_to_latex(sv2, prefix="\\text{Statevector 2} = "))

display(plot_histogram(counts))
# Out:
# $$
# \text{Statevector 1} =
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$
# $$
# \text{Statevector 2} =
# \begin{bmatrix}
# 1 & 0 & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 14
#      12 import qiskit as qk
#      13 #import numpy as np
# ---> 14 circuit = qk.load_qasm_string(qasm)
#      15 result = qk.execute(circuit, 'local_unitary_simulator').result()
#      16 print(np.round(result.get_unitary(), 1))
#
# AttributeError: module 'qiskit' has no attribute 'load_qasm_string'
